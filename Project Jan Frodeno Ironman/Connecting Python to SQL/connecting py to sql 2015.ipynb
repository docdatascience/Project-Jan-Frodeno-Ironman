# %%
import pyodbc

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                     'Server=DESKTOP-NJS1MI9\SQLEXPRESS;'
                     'Database=Ironman_JF;'
                     'Trusted_Connection =yes;')
cursor = conn.cursor()
cursor.execute('SELECT * FROM [Ironman_JF].[dbo].[2015]')
for row in cursor:
    print(row)
# Out:
# (1, 'Swim_tot', None, 3.8, 3.8, '2015-10-10 00:50:00.0000000', '2015-10-10 00:50:00.0000000', 4.6, -3.4, None)
# (2, 'Transition_1', None, None, 3.8, '2015-10-10 00:52:00.0000000', '2015-10-10 00:01:00.0000000', None, -0.3, None)
# (3, None, 'Bike', 8.0, 11.8, '2015-10-10 01:05:00.0000000', '2015-10-10 00:12:00.0000000', 38.3, 0.0, '26.1')
# (4, None, 'Bike', 12.6, 16.4, '2015-10-10 01:09:00.0000000', '2015-10-10 00:04:00.0000000', 64.9, 0.0, '26.1')
# (5, None, 'Bike', 18.3, 22.1, '2015-10-10 01:18:00.0000000', '2015-10-10 00:08:00.0000000', 40.0, 0.0, '26.1')
# (6, None, 'Bike', 50.7, 54.5, '2015-10-10 02:03:00.0000000', '2015-10-10 00:45:00.0000000', 42.4, 0.0, '26.1')
# (7, None, 'Bike', 70.2, 74.0, '2015-10-10 02:34:00.0000000', '2015-10-10 00:31:00.0000000', 37.6, -0.8, '26.1')
# (8, None, 'Bike', 96.9, 100.7, '2015-10-10 03:17:00.0000000', '2015-10-10 00:42:00.0000000', 37.5, -2.0, '30')
# ...

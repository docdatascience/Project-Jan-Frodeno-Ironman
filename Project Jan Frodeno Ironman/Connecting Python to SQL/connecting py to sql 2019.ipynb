# %%
import pyodbc

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                     'Server=DESKTOP-NJS1MI9\SQLEXPRESS;'
                     'Database=Ironman_JF;'
                     'Trusted_Connection =yes;')
cursor = conn.cursor()
cursor.execute('SELECT * FROM [Ironman_JF].[dbo].[2019]')

for row in cursor:
    print(row)
# Out:
# (1, 'Swim_tot', None, 3.9, 3.9, '2019-10-12 00:47:00.0000000', '2019-10-12 00:47:00.0000000', 4.9, None)
# (2, 'Transition_1', None, None, 3.9, '2019-10-12 00:49:00.0000000', '2019-10-12 00:01:00.0000000', None, None)
# (3, None, 'Bike', 3.5, 7.4, '2019-10-12 00:55:00.0000000', '2019-10-12 00:06:00.0000000', 34.9, '25')
# (4, None, 'Bike', 7.5, 11.4, '2019-10-12 01:01:00.0000000', '2019-10-12 00:06:00.0000000', 37.0, '25')
# (5, None, 'Bike', 14.1, 18.0, '2019-10-12 01:10:00.0000000', '2019-10-12 00:08:00.0000000', 47.4, '25')
# (6, None, 'Bike', 23.7, 27.6, '2019-10-12 01:23:00.0000000', '2019-10-12 00:13:00.0000000', 43.5, '25')
# (7, None, 'Bike', 37.6, 41.5, '2019-10-12 01:43:00.0000000', '2019-10-12 00:19:00.0000000', 42.7, '25')
# (8, None, 'Bike', 50.4, 54.3, '2019-10-12 01:59:00.0000000', '2019-10-12 00:16:00.0000000', 45.6, '25')
# (9, None, 'Bike', 67.5, 71.4, '2019-10-12 02:24:00.0000000', '2019-10-12 00:24:00.0000000', 41.3, '26.1')
# ...
